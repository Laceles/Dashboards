# %%
import pandas as pd 
df = pd.read_csv("risco_credito_regras.csv")
df
# Out:
#         historia divida garantias     renda     risco
# 0           ruim   alta   nenhuma      0_15      alto
# 1   desconhecida   alta   nenhuma     15_35      alto
# 2   desconhecida  baixa   nenhuma     15_35  moderado
# 3   desconhecida  baixa   nenhuma  acima_35      alto
# 4   desconhecida  baixa   nenhuma  acima_35     baixo
# 5   desconhecida  baixa  adequada  acima_35     baixo
# 6           ruim  baixa   nenhuma      0_15      alto
# 7           ruim  baixa  adequada  acima_35  moderado
# 8            boa  baixa   nenhuma  acima_35     baixo
# 9            boa   alta  adequada  acima_35     baixo
# 10           boa   alta   nenhuma      0_15      alto
# 11           boa   alta   nenhuma     15_35  moderado
# 12           boa   alta   nenhuma  acima_35     baixo
# 13          ruim   alta   nenhuma     15_35      alto

# %%
#lista = list(df['historia'].unique())
filtered_data = df.loc[df['historia'] == "ruim" ]
filtered_data
# Out:
#    historia divida garantias     renda   c#risco
# 0      ruim   alta   nenhuma      0_15      alto
# 6      ruim  baixa   nenhuma      0_15      alto
# 7      ruim  baixa  adequada  acima_35  moderado
# 13     ruim   alta   nenhuma     15_35      alto

# %%
divida_names = list(df['divida'].unique())
divida_count = list(df['divida'].value_counts().values)
df_divida = pd.DataFrame({'names': divida_names, 'counts': divida_count})
df_divida
# Out:
#    names  counts
# 0   alta       7
# 1  baixa       7

# %%
df = pd.read_csv("risco_credito_regras.csv")
x = input()
print(x)
y = input()
print(y)
garantias  = [list(df['historia'].unique()) if x == "Todos" else x ]
print(garantias)
historia  = [list(df['garantias'].unique()) if x == "Todos" else y ]
print(historia)
df_filtered = df.loc[(df['garantias'].isin(garantias)) & (df['historia'].isin(historia))]
df_filtered
# Out:
# ruim
# nenhuma
# ['ruim']
# ['nenhuma']
# Empty DataFrame
# Columns: [historia, divida, garantias, renda, c#risco]
# Index: []

# %%
colors = {
        "Light":{
            'background':'xxxxx1',
            'font':'xxxxx2',
            'paper':'xxxxx3',
            'title':'xxxxx4'
                },
        "Dark":{
            'background':'xxxxx5',
            'font':'xxxxx6',
            'paper':'xxxxx7',
            'title':'xxxxx8'
                }
            }
col = colors['Dark']
print(col['background'])
print(col['font'])
print(col['paper'])
print(col['title'])
# Out:
# xxxxx5
# xxxxx6
# xxxxx7
# xxxxx8
